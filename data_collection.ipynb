# %% [markdown]
# # Data Collection

# %% [markdown]
# ## Speech Scraper
# Data scientists often need to find creative ways to obtain data relevant for an analysis. Webscraping is a common method data scientists use to get web data.
#
# Here, we are going to obtain the Secretary of Defense's public speeches from 2014 through the present. These speeches are available online here but there are over 200 of them. So, we will build a quick scraper to collect them.
#
# First, let's import a few key packages:
#
# 1. requests: this allows us to make requests to webpages
# 2. BeautifulSoup: this is a handy tool for parsing websites
# 3. pandas: this allows us to manipulate tabular data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# First, we need to have our scraper navigate to [https://www.state.gov/secretary/remarks/2018/](https://www.state.gov/secretary/remarks/2018/) which has a link to each of the Secretary's remarks for 2018

# %%
def get_soup():
    url = "https://www.state.gov/secretary/remarks/2018/"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    return soup

# %% [markdown]
# Next, we need to extract the links (_to just the remarks_) from this page.

# %%
def get_links(soup):
    links = []
    content = soup.find('div', {'class': 'l-wrap'})
    for a in content.findAll('a'):
        links.append(a['href'])
    print(str(len(links)) + " speeches were found")
    return links

# %% [markdown]
# Now, we can take any of the links we found and extract the following:
#
# * Title
# * Date
# * Speech
# * URL

# %%
def get_remarks(link):
    url = "http://www.state.gov" + link
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    
    title = soup.find('h2', {'id': 'page-title'}).text
    date = soup.find('div', {'id': 'date_long'}).text
    content = soup.find('div', {'id': 'centerblock'})
    speech = ''
    for p in content.findAll('p'):
        speech += p.text + '\n'
    
    speech_object = {'url': url,
                     'title': title,
                     'date': date,
                     'speech': speech}
    return speech_object

# %% [markdown]
# Finally, we should just run our scraper!

# %%
speeches = []
base = get_soup()
links = get_links(base)
count = 1
for link in links:
    speech = get_remarks(link)
    speeches.append(speech)
    print("{0}: {1}".format(count, speech['title']))
    count += 1
# Out:
# 398 speeches were found
# 1: On the Occasion of Christmas
# 2: Interview With Steve Inskeep of NPR
# 3: Interview With Brian Grimmett of KMUW Wichita Public Radio
# 4: Interview With Bryce Dolan of 550 KFRM-AM
# 5: Interview With Laura Ingraham of The Laura Ingraham Show
# 6: Interview With Steve and Ted in the Morning of KNSS Radio
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-363d34dc1863> in <module>
#       4 count = 1
#       5 for link in links:
# ----> 6     speech = get_remarks(link)
#       7     speeches.append(speech)
#       8     print("{0}: {1}".format(count, speech['title']))
#
# <ipython-input-9-66f0b9d8def3> in get_remarks(link)
#       1 def get_remarks(link):
#       2     url = "http://www.state.gov" + link
# ----> 3     response = requests.get(url)
#       4     soup = BeautifulSoup(response.text, "html.parser")
#       5
#
# ~/anaconda/envs/p3/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda/envs/p3/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda/envs/p3/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda/envs/p3/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# ~/anaconda/envs/p3/lib/python3.5/site-packages/requests/sessions.py in <listcomp>(.0)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# ~/anaconda/envs/p3/lib/python3.5/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     245                     proxies=proxies,
#     246                     allow_redirects=False,
# --> 247                     **adapter_kwargs
#     248                 )
#     249
#
# ~/anaconda/envs/p3/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda/envs/p3/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda/envs/p3/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda/envs/p3/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         # Trigger any extra validation we need to do.
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#     348             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda/envs/p3/lib/python3.5/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     848         # Force connect early to allow us to validate the connection.
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#     852         if not conn.is_verified:
#
# ~/anaconda/envs/p3/lib/python3.5/site-packages/urllib3/connection.py in connect(self)
#     282     def connect(self):
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#     286         hostname = self.host
#
# ~/anaconda/envs/p3/lib/python3.5/site-packages/urllib3/connection.py in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# ~/anaconda/envs/p3/lib/python3.5/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      71             if source_address:
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#      75
#
# KeyboardInterrupt:

# %% [markdown]
# Now we can make a dataframe (a table) from the speeches:

# %%
df = pd.DataFrame.from_records(speeches)

# %% [markdown]
# Let's make sure that the speeches are at least 1000 characters in length. Otherwise, it might be junk data.

# %%
df = df[df.speech.str.len() > 500 ]

# %% [markdown]
# Now, we can see that we collected 384 speeches which meet the criteria.

# %%
df.shape
# Out:
# (384, 4)

# %% [markdown]
# Finally, we can save these speeches as a .csv file for future use!

# %%
df.to_csv('datasets/SecState_Speeches.csv', index=False)

# %% [markdown]
# ## Streaming data from an API
# Let's connect to an API. We'll use the Twitter API for our example. First we need to load up a couple Twitter related Python libraries.

# %%
import twitter
import tweepy

# %% [markdown]
# Next, I need to load in my Twitter API credentials.

# %%
credentials = {}
with open('/Users/brandon/Google Drive/Python/Twitter Credentials/twitter_credentials.txt','r') as f:
    for line in f:
        cred_item = line.split(':')
        credentials[cred_item[0]] = cred_item[1].strip()
        
auth = tweepy.OAuthHandler(credentials['Consumer_Key'], credentials['Consumer_Secret'])

auth.set_access_token(credentials['Access_token'], credentials['Access_secret'])

# %% [markdown]
# Now, I instantiate a connection to the Twitter API.

# %%
api = tweepy.API(auth)

# %% [markdown]
# Finally, I can perform a search:

# %%
query = '#venezuela'
search_results = []

for status in tweepy.Cursor(api.search, q=query, ).items(100):
    #access the json property of the status object by appending ._json to the status item
    tweet = status._json
    search_results.append(tweet)
    print("User: {}".format(tweet['user']['screen_name']))
    print("Tweet: {}".format(tweet['text']))    
    print('\n')
# Out:
# User: Threwlys1
# Tweet: RT @RenovaMidia: O presidente interino da #Venezuela, Juan Guaidó, convocou dois novos protestos contra a ditadura de Nicolás Maduro.
#
# http…
#
#
# User: Patinahat2
# Tweet: RT @OffGuardian0: Before you buy into the mainstream narrative on #Venezuela, you have to ask yourself:
#
# "Why would the #US &amp; #UK govts, st…
#
#
# User: Marte_Ven1
# Tweet: Ninguno de esos vividores se quiere devolver a pasar roncha en #Venezuela. Aprovechen cuerda de chulos, cuando haya… https://t.co/mlxyixn5d8
#
#
# User: Nimayee1
# Tweet: RT @Mojahedineng: "... it is obvious that the Iranian regime’s main concern is about its own future."
# #Iran
# #Venezuela
# https://t.co/QrOww3f…
#
#
# User: oscar_a_f
# Tweet: RT @micheldoueihi: -¡Buenos días!
# #29Ene #FelizMartes # PDVSAEsDelPueblo Pedro Carreño Día del Trabajador Social #primerapagina #Venezuela…
#
#
# User: pamavi66
# Tweet: RT @bitMomentum: Trending ahora en Izquierda/Centro Izqda.:
# ➀ #psoe ↑
# ➁ #espana ↑
# ➂ #doshermanas ↑
# ➃ #venezuela ↓
# ➄ #felizmartes ↑
# ➅ #…
#
#
# User: CasiopeaLH
# Tweet: RT @lajornadaonline: #Venezuela | Estados Unidos dio a conocer las nuevas medidas que buscan respaldar al autoproclamado presidente @jguaid…
#
#
# User: EUSEBIORUIZZ
# Tweet: RT @tuiteros_vzla: La etiqueta #FANBActivaPorLaPatria entró a las tendencias de #Venezuela a las 07:00 AM
#
#
# User: bulto1973
# Tweet: RT @CarlosFdeCossio: Declaraciones amenazadoras y mendaces del Asesor de Seguridad Nacional de EEUU contra #Cuba merecen rechazo más enérgi…
#
#
# User: carmenzavaleta3
# Tweet: RT @CaraotaDigital: Juan Guaidó afirmó haber tomado control de los activos de #Venezuela en el exterior              ``              https:…
#
#
# User: Pandora350
# Tweet: RT @marianodealba: Reuters: Viceministro de Finanzas de #Rusia declaró que aunque está consciente de los problemas por sanciones de #EEUU,…
#
#
# User: laurenciobeltra
# Tweet: RT @ObservadBinario: #BIN Quien no conoce mi país, #Venezuela, con todos los paisajes del mundo en un solo territorio, mar, llanos, montaña…
#
#
# User: BenitoAtos
# Tweet: RT @CaraotaDigital: #LoMásLeído #Rusia vs. #EEUU por #Venezuela: “Lamentamos que este juego sucio llegue hasta el Consejo de Seguridad”…
#
#
# User: oscar_a_f
# Tweet: RT @YoMigrante: #29Ene Bs Ds. Colaboremos con @jguaido y su cancillería. ¿Qué sugieren? ¿Ratificar a Jorge Arreaza como Canciller, o, Desig…
#
#
# User: AlRomanMppef
# Tweet: RT @madeleintlSUR: El cara a cara de #EEUU y #Rusia se mueve la geopolítica #mundial la gran diferencia es la defensa de lo legal, el respe…
#
#
# User: UNolizer
# Tweet: #NicolásMaduro encarcela a 77 niños y los acusa de terrorismo #Venezuela #LiberenANiñosYAdolescentes...… https://t.co/Yyd6gRm987
#
#
# User: PaprikaPink
# Tweet: RT @W7VOA: Update: https://t.co/a4XfrsrrW0 #Colombia #Venezuela @AmbJohnBolton
#
#
# User: MariaSolangeMa7
# Tweet: RT @steve_hanke: Tensions high over #Venezuela at the @UN. Spain, Germany, France &amp; UK vowed to support crowned king #Guaidó, &amp; gave #Madur…
#
#
# User: mcl2306
# Tweet: RT @madeleintlSUR: #Maduro| Con esa acción contra @PDVSA EEUU quiere robar a #Venezuela CITGO. Ordené acciones  políticas, legales ante tri…
#
#
# User: julio2j
# Tweet: RT @El_Cooperante: Funcionaria de la Embajada de #Venezuela🇻🇪 en Texas reconoce a Juan Guaidó como “presidente encargado”  https://t.co/aTr…
#
#
# User: lilita70
# Tweet: RT @marianodealba: Reuters: Viceministro de Finanzas de #Rusia declaró que aunque está consciente de los problemas por sanciones de #EEUU,…
#
#
# User: FotolibrosI
# Tweet: RT @lajornadaonline: #Venezuela | Estados Unidos dio a conocer las nuevas medidas que buscan respaldar al autoproclamado presidente @jguaid…
#
#
# User: Marbella1604
# Tweet: RT @anajuljatar: Mi hija y mi héroe ⁦@Joannahausmann⁩ explica en inglés lo q sucede en #venezuela dale RT si te parece: What's Happening in…
#
#
# User: corderoenvivo
# Tweet: RT @Ruptly: Hundreds rally in support of #Venezuela's #Maduro in #Gaza City
# #Palestine https://t.co/UzFmjwPdQJ
#
#
# User: pacoxtam
# Tweet: @Milenio @robertayque Aun cuando algunos nostálgicos por ahí de épocas pasadas siguen asegurando que si... aunque l… https://t.co/Q4MY1kXNOC
#
#
# User: zarazacandanga
# Tweet: RT @jcyckerubin: #EEUU envía 5.000 soldados a #Colombia, esas bases no era para controlar el cultivo y el tráfico de drogas? Lo extraño es…
#
#
# User: celesbass
# Tweet: RT @GuaidoPresiden1: Para que #LiberenANiñosYAdolescentes Yo salgo el #29Ene para volver a tomar a #Venezuela https://t.co/HHU0Xg4TbQ
#
#
# User: johnnywgv
# Tweet: Ayer lo dije pareciera inevitable este conflicto en #Venezuela https://t.co/QdDZO6flTO

# %% [markdown]
# ### Accessing Tweets by Location
#
# Set locations using lat, long for U.S. Embassy Caracas 10.478073, -66.871375

# %%
embassy = api.trends_closest('10.478073', '-66.871375')
print(embassy)
# Out:
# [{'country': 'Venezuela', 'parentid': 23424982, 'woeid': 395269, 'url': 'http://where.yahooapis.com/v1/place/395269', 'name': 'Caracas', 'placeType': {'name': 'Town', 'code': 7}, 'countryCode': 'VE'}]

# %%
geo_trends = api.trends_place(embassy[0]['woeid'])

for i in geo_trends[0]['trends']:
    print(i['name'])
# Out:
# #GuaidoChallenge
# #GuaidoPatasCortas
# #GuaidoLosTieneLocos
# #GuaidóSeVacilóADiosdado
# #apostilla
# Jorge Rodríguez
# Hotel Lido
# Elliott Abrams
# Valentina
# diosdado y bernal
# Plaza Alfredo Sadel
# JULIANTINA VS HOMOFOBIA
# Banco de Inglaterra
# Cabello y Bernal
# Asamblea Popular
# "Pablito"
# totalán
# Diosdi
# Guaidó y Bernal
# Málaga
# Consulado de Venezuela
# Mr. Trump
# Roberto Marrero
# Héctor Manrique
# Brumadinho
# Pablo Casado
# tesoro de eeuu
# Franklin Virguez
# Es Guaidó
# TransMiranda
# Alicia Machado
# Metro de Oeste a Este
# Plaza Bolívar de Chacao
# RCTV
# Juan Guaidó
# Estados Unidos
# Houston
# #Julen
# #concluGUAIDÓMADURO
# #26Ene
# #TodosSomosGuaido
# #JorgeRodriguezCabezaeguebo
# #GuaidoSeLosVacilo
# #UnidadYLealtadConNicolas
# #VzlaConLaANPorLaLibertad
# #GuaidoEsMiPresidenteOK
# #VenezuelaYElMundoConMaduro
# #winstonmascaguebo
# #Petare
# #elmundoconvzla

# %% [markdown]
# ## Checking our usage limits

# %%
api_status = api.rate_limit_status()

# %%
api_status
# Out:
# {'rate_limit_context': {'access_token': '188015457-qiXHARsYFRFecKwHWNAhZMusgoPQZarcITY0aNus'},
#  'resources': {'account': {'/account/login_verification_enrollment': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/account/personalization/sync_optout_settings&POST': {'limit': 200,
#     'remaining': 200,
#     'reset': 1548476542},
#    '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1548476542},
#    '/account/update_profile': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/account/verify_credentials': {'limit': 75,
#     'remaining': 75,
#     'reset': 1548476542}},
#   'account_activity': {'/account_activity/all/:instance_name/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1548476542},
#    '/account_activity/all/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/account_activity/all/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/account_activity/direct_messages/:instance_name/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/account_activity/direct_messages/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/account_activity/direct_messages/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/account_activity/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1548476542},
#    '/account_activity/webhooks/:id/subscriptions/all': {'limit': 500,
#     'remaining': 500,
#     'reset': 1548476542},
#    '/account_activity/webhooks/:id/subscriptions/all/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages': {'limit': 500,
#     'remaining': 500,
#     'reset': 1548476542},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542}},
#   'application': {'/application/rate_limit_status': {'limit': 180,
#     'remaining': 179,
#     'reset': 1548476542}},
#   'auth': {'/auth/csrf_token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542}},
#   'blocks': {'/blocks/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/blocks/list': {'limit': 15, 'remaining': 15, 'reset': 1548476542}},
#   'business_experience': {'/business_experience/dashboard_features': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542},
#    '/business_experience/dashboard_settings/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542},
#    '/business_experience/dashboard_settings/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542},
#    '/business_experience/dashboard_settings/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542},
#    '/business_experience/keywords': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542}},
#   'collections': {'/collections/entries': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1548476542},
#    '/collections/list': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1548476542},
#    '/collections/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1548476542}},
#   'contacts': {'/contacts/addressbook': {'limit': 300,
#     'remaining': 300,
#     'reset': 1548476542},
#    '/contacts/delete/status': {'limit': 300,
#     'remaining': 300,
#     'reset': 1548476542},
#    '/contacts/uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1548476542},
#    '/contacts/users': {'limit': 300, 'remaining': 300, 'reset': 1548476542},
#    '/contacts/users_and_uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1548476542}},
#   'custom_profiles': {'/custom_profiles/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1548476542},
#    '/custom_profiles/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1548476542}},
#   'device': {'/device/token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542}},
#   'direct_messages': {'/direct_messages': {'limit': 300,
#     'remaining': 300,
#     'reset': 1548476542},
#    '/direct_messages/broadcasts/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1548476542},
#    '/direct_messages/broadcasts/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1548476542},
#    '/direct_messages/broadcasts/statuses/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1548476542},
#    '/direct_messages/broadcasts/statuses/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1548476542},
#    '/direct_messages/events/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/direct_messages/events/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/direct_messages/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1548476542},
#    '/direct_messages/sent': {'limit': 300,
#     'remaining': 300,
#     'reset': 1548476542},
#    '/direct_messages/sent_and_received': {'limit': 300,
#     'remaining': 300,
#     'reset': 1548476542},
#    '/direct_messages/show': {'limit': 300,
#     'remaining': 300,
#     'reset': 1548476542},
#    '/direct_messages/subscribers/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1548476542},
#    '/direct_messages/subscribers/lists/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1548476542},
#    '/direct_messages/subscribers/lists/members/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1548476542},
#    '/direct_messages/subscribers/lists/members/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1548476542},
#    '/direct_messages/subscribers/lists/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1548476542},
#    '/direct_messages/subscribers/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1548476542}},
#   'drafts': {'/drafts/statuses/create': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542},
#    '/drafts/statuses/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542},
#    '/drafts/statuses/ids': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542},
#    '/drafts/statuses/list': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542},
#    '/drafts/statuses/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542},
#    '/drafts/statuses/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542}},
#   'favorites': {'/favorites/list': {'limit': 75,
#     'remaining': 75,
#     'reset': 1548476542}},
#   'feedback': {'/feedback/events': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1548476542},
#    '/feedback/show/:id': {'limit': 180,
#     'remaining': 180,
#     'reset': 1548476542}},
#   'followers': {'/followers/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1548476542}},
#   'friends': {'/friends/following/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/friends/following/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/friends/ids': {'limit': 15, 'remaining': 15, 'reset': 1548476542},
#    '/friends/list': {'limit': 15, 'remaining': 15, 'reset': 1548476542}},
#   'friendships': {'/friendships/incoming': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/friendships/list': {'limit': 200, 'remaining': 200, 'reset': 1548476542},
#    '/friendships/lookup': {'limit': 15, 'remaining': 15, 'reset': 1548476542},
#    '/friendships/no_retweets/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/friendships/outgoing': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/friendships/show': {'limit': 180, 'remaining': 180, 'reset': 1548476542}},
#   'geo': {'/geo/id/:place_id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1548476542},
#    '/geo/reverse_geocode': {'limit': 15, 'remaining': 15, 'reset': 1548476542},
#    '/geo/search': {'limit': 15, 'remaining': 15, 'reset': 1548476542},
#    '/geo/similar_places': {'limit': 15, 'remaining': 15, 'reset': 1548476542}},
#   'graphql&POST': {'/graphql&POST': {'limit': 2500,
#     'remaining': 2500,
#     'reset': 1548476542}},
#   'guide': {'/guide': {'limit': 180, 'remaining': 180, 'reset': 1548476542}},
#   'help': {'/help/configuration': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/help/languages': {'limit': 15, 'remaining': 15, 'reset': 1548476542},
#    '/help/privacy': {'limit': 15, 'remaining': 15, 'reset': 1548476542},
#    '/help/settings': {'limit': 15, 'remaining': 15, 'reset': 1548476542},
#    '/help/tos': {'limit': 15, 'remaining': 15, 'reset': 1548476542}},
#   'i': {'/i/config': {'limit': 15, 'remaining': 15, 'reset': 1548476542}},
#   'lists': {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1548476542},
#    '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1548476542},
#    '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1548476542},
#    '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1548476542},
#    '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1548476542},
#    '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1548476542},
#    '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1548476542},
#    '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1548476542},
#    '/lists/subscribers/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/lists/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542}},
#   'live_pipeline': {'/live_pipeline/events': {'limit': 180,
#     'remaining': 180,
#     'reset': 1548476542}},
#   'live_video_stream': {'/live_video_stream/status/:id': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1548476542}},
#   'media': {'/media/upload': {'limit': 500,
#     'remaining': 500,
#     'reset': 1548476542}},
#   'moments': {'/moments/permissions': {'limit': 300,
#     'remaining': 300,
#     'reset': 1548476542},
#    '/moments/statuses/update': {'limit': 5,
#     'remaining': 5,
#     'reset': 1548476542}},
#   'mutes': {'/mutes/users/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/mutes/users/list': {'limit': 15, 'remaining': 15, 'reset': 1548476542}},
#   'oauth': {'/oauth/invalidate_token': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542}},
#   'safety': {'/safety/detection_feedback': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1548476542}},
#   'sandbox': {'/sandbox/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1548476542}},
#   'saved_searches': {'/saved_searches/destroy/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/saved_searches/list': {'limit': 15, 'remaining': 15, 'reset': 1548476542},
#    '/saved_searches/show/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542}},
#   'search': {'/search/tweets': {'limit': 180,
#     'remaining': 159,
#     'reset': 1548476075}},
#   'statuses': {'/statuses/friends': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/statuses/home_timeline': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/statuses/lookup': {'limit': 900, 'remaining': 900, 'reset': 1548476542},
#    '/statuses/mentions_timeline': {'limit': 75,
#     'remaining': 75,
#     'reset': 1548476542},
#    '/statuses/oembed': {'limit': 180, 'remaining': 180, 'reset': 1548476542},
#    '/statuses/retweeters/ids': {'limit': 75,
#     'remaining': 75,
#     'reset': 1548476542},
#    '/statuses/retweets/:id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1548476542},
#    '/statuses/retweets_of_me': {'limit': 75,
#     'remaining': 75,
#     'reset': 1548476542},
#    '/statuses/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1548476542},
#    '/statuses/user_timeline': {'limit': 900,
#     'remaining': 900,
#     'reset': 1548476542}},
#   'traffic': {'/traffic/map': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542}},
#   'trends': {'/trends/available': {'limit': 75,
#     'remaining': 75,
#     'reset': 1548476542},
#    '/trends/closest': {'limit': 75, 'remaining': 73, 'reset': 1548476460},
#    '/trends/place': {'limit': 75, 'remaining': 74, 'reset': 1548476514}},
#   'tweet_prompts': {'/tweet_prompts/report_interaction': {'limit': 180,
#     'remaining': 180,
#     'reset': 1548476542},
#    '/tweet_prompts/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1548476542}},
#   'tweets': {'/tweets/search/:product/:instance/counts': {'limit': 900,
#     'remaining': 900,
#     'reset': 1548476542},
#    '/tweets/search/:product/:label': {'limit': 1800,
#     'remaining': 1800,
#     'reset': 1548476542},
#    '/tweets/stream/filter/:instance_name': {'limit': 50,
#     'remaining': 50,
#     'reset': 1548476542},
#    '/tweets/stream/filter/rules': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542},
#    '/tweets/stream/filter/rules/:instance_name&DELETE': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542},
#    '/tweets/stream/filter/rules/:instance_name&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542},
#    '/tweets/stream/filter/rules/:instance_name/:rule_id': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542},
#    '/tweets/stream/filter/rules/:instance_name/validation&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1548476542}},
#   'users': {'/users/contributees/pending': {'limit': 200,
#     'remaining': 200,
#     'reset': 1548476542},
#    '/users/contributors/pending': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1548476542},
#    '/users/derived_info': {'limit': 15, 'remaining': 15, 'reset': 1548476542},
#    '/users/lookup': {'limit': 900, 'remaining': 900, 'reset': 1548476542},
#    '/users/profile_banner': {'limit': 180,
#     'remaining': 180,
#     'reset': 1548476542},
#    '/users/report_spam': {'limit': 15, 'remaining': 15, 'reset': 1548476542},
#    '/users/search': {'limit': 900, 'remaining': 900, 'reset': 1548476542},
#    '/users/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1548476542},
#    '/users/suggestions': {'limit': 15, 'remaining': 15, 'reset': 1548476542},
#    '/users/suggestions/:slug': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/users/suggestions/:slug/members': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542}},
#   'webhooks': {'/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542},
#    '/webhooks/subscriptions/direct_messages': {'limit': 15,
#     'remaining': 15,
#     'reset': 1548476542}}}}

# %% [markdown]
# # NOAA Weather API

# %%
import requests

# %%
token = open('/Users/brandon/Google Drive/Python/noaa_credentials.txt').read().split('\n')[0]

# %%
locations = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/locations'

# %%
response = requests.get(locations, headers={'token': token})

# %%
locations_json = response.json()

# %%
sample = locations_json['results'][2]

# %%
sample
# Out:
# {'datacoverage': 0.9991,
#  'id': 'CITY:AE000003',
#  'maxdate': '2019-01-28',
#  'mindate': '1944-03-01',
#  'name': 'Dubai, AE'}

# %%
gsom = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GSOM&locationid={}&startdate=2016-01-01&enddate=2018-01-01'.format(sample['id'])#&units=standard&startdate=2010-05-01&enddate=2010-05-31'

# %%
response = requests.get(gsom, headers={'token': token})

# %%
gsom_json = response.json()

# %%
gsom_json
# Out:
# {'metadata': {'resultset': {'count': 10, 'limit': 25, 'offset': 1}},
#  'results': [{'attributes': '5,S',
#    'datatype': 'DP01',
#    'date': '2017-04-01T00:00:00',
#    'station': 'GHCND:AEM00041194',
#    'value': 0},
#   {'attributes': '5,S',
#    'datatype': 'DP10',
#    'date': '2017-04-01T00:00:00',
#    'station': 'GHCND:AEM00041194',
#    'value': 0},
#   {'attributes': '5,S',
#    'datatype': 'DP1X',
#    'date': '2017-04-01T00:00:00',
#    'station': 'GHCND:AEM00041194',
#    'value': 0},
#   {'attributes': '5,,S,30,+',
#    'datatype': 'EMXP',
#    'date': '2017-04-01T00:00:00',
#    'station': 'GHCND:AEM00041194',
#    'value': 0},
#   {'attributes': '5,,,S',
#    'datatype': 'PRCP',
#    'date': '2017-04-01T00:00:00',
#    'station': 'GHCND:AEM00041194',
#    'value': 0},
#   {'attributes': '4,S',
#    'datatype': 'DX32',
#    'date': '2017-07-01T00:00:00',
#    'station': 'GHCND:AE000041196',
#    'value': 0},
#   {'attributes': '4,S',
#    'datatype': 'DX70',
#    'date': '2017-07-01T00:00:00',
#    'station': 'GHCND:AE000041196',
#    'value': 27},
#   {'attributes': '4,S',
#    'datatype': 'DX90',
#    'date': '2017-07-01T00:00:00',
#    'station': 'GHCND:AE000041196',
#    'value': 27},
#   {'attributes': '4,S,23,',
#    'datatype': 'EMXT',
#    'date': '2017-07-01T00:00:00',
#    'station': 'GHCND:AE000041196',
#    'value': 47.1},
#   {'attributes': '4,,,S',
#    'datatype': 'TMAX',
#    'date': '2017-07-01T00:00:00',
#    'station': 'GHCND:AE000041196',
#    'value': 44.33}]}

# %% [markdown]
# # CoreNLP Service

# %%
from pycorenlp import StanfordCoreNLP
import json

# %%
text = 'Brandon is running for president of the U.S. in 2020.'

# %%
nlp = StanfordCoreNLP('http://52.20.193.246:9000')
res = nlp.annotate(text,
                   properties={
                       'annotators': 'ner',
                       'outputFormat': 'json',
                       'timeout': 1000
                         })

# %%
for token in res['sentences'][0]['tokens']:
    if token['ner'] in ['PERSON','LOCATION','DATE']:
        print('{0}: {1}'.format(token['ner'], token['word']))
# Out:
# PERSON: Brandon
# LOCATION: U.S.
# DATE: 2020
